# %%
from transformers import BertTokenizerFast, BertForQuestionAnswering, pipeline, \
                         DataCollatorWithPadding, TrainingArguments, Trainer, \
                         AutoModelForQuestionAnswering, AutoTokenizer

from datasets import Dataset
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from bs4 import BeautifulSoup
import requests

# %%
bert_tokenizer = BertTokenizerFast.from_pretrained('bert-large-uncased', return_token_type_ids = True)
qa_bert = BertForQuestionAnswering.from_pretrained('bert-large-uncased')
# Out:
# Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at bert-large-uncased and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
df = pd.read_parquet('data/train-00000-of-00001 (1).parquet')
df.to_csv('qa.csv')

# %%
df = pd.read_csv('data/qa.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                                        id  title  \
# 0           0  7ba1e8f4261d3170fcf42e84a81dd749116fae95  Brain
# 1           1  5ec5ef305a259311596e85d811ade30bd68b079d  Brain
# 2           2  7cb230edfb15ad1fda8d157af1f2b574cbb02b4c  Brain
# 3           3  e1850f2a48b8f7c2231cec41ed63c1b638a8e2c7  Brain
# 4           4  7bc0ae1a8a24ea4f3398b5236ab9569bbc3e820b  Brain
#
#                                              context  \
# 0  Another approach to brain function is to exami...
# 1  Another approach to brain function is to exami...
# 2  Another approach to brain function is to exami...
# 3  Another approach to brain function is to exami...
# 4  Another approach to brain function is to exami...
#
#                                             question  \
# 0   What sare the benifts of the blood brain barrir?
# 1         What is surrounded by cerebrospinal fluid?
# 2                       What does the skull protect?
# 3  What has been injected into rats to produce pr...
# 4    What can cause issues with how the brain works?
#
#                                              answers  \
# 0  {'text': array(['isolated from the bloodstream...
# 1  {'text': array(['brain'], dtype=object), 'answ...
# 2  {'text': array(['brain'], dtype=object), 'answ...
# 3  {'text': array(['chemicals'], dtype=object), '...
# 4  {'text': array(['brain damage'], dtype=object)...
#
#                                             metadata
# 0  {'split': 'train', 'model_in_the_loop': 'Combi...
# 1  {'split': 'train', 'model_in_the_loop': 'Combi...
# 2  {'split': 'train', 'model_in_the_loop': 'Combi...
# 3  {'split': 'train', 'model_in_the_loop': 'Combi...
# 4  {'split': 'train', 'model_in_the_loop': 'Combi...

# %%
df.shape
# Out:
# (30000, 7)

# %%
df.iloc[0]
# Out:
# Unnamed: 0                                                    0
# id                     7ba1e8f4261d3170fcf42e84a81dd749116fae95
# title                                                     Brain
# context       Another approach to brain function is to exami...
# question       What sare the benifts of the blood brain barrir?
# answers       {'text': array(['isolated from the bloodstream...
# metadata      {'split': 'train', 'model_in_the_loop': 'Combi...
# Name: 0, dtype: object

# %%
df.iloc[0].context.find("isolated from the bloodstream")
# Out:
# 195

# %%
df.iloc[0].answers[17:]
# Out:
# "isolated from the bloodstream'], dtype=object), 'answer_start': array([195])}"

# %%
df.iloc[0].answers.find(']')
# Out:
# 47

# %%
df.iloc[0].answers[17:df.iloc[0].answers.find("]")-1]
# Out:
# 'isolated from the bloodstream'

# %%
qa_df = df[['question','context']]

# %%
qa_df
# Out:
#                                                 question  \
# 0       What sare the benifts of the blood brain barrir?
# 1             What is surrounded by cerebrospinal fluid?
# 2                           What does the skull protect?
# 3      What has been injected into rats to produce pr...
# 4        What can cause issues with how the brain works?
# ...                                                  ...
# 29995                  What is the lowest ISO mentioned?
# 29996                 What is the highest ISO mentioned?
# 29997              What is Kodak'sbrand name of E6 film?
# 29998                         How do these films differ?
# 29999  What letter designates what Ektachrome is desi...
#
#                                                  context
# 0      Another approach to brain function is to exami...
# 1      Another approach to brain function is to exami...
# 2      Another approach to brain function is to exami...
# 3      Another approach to brain function is to exami...
# 4      Another approach to brain function is to exami...
# ...                                                  ...
# 29995  Some high-speed black-and-white films, such as...
# 29996  Some high-speed black-and-white films, such as...
# 29997  Some high-speed black-and-white films, such as...
# 29998  Some high-speed black-and-white films, such as...
# 29999  Some high-speed black-and-white films, such as...
#
# [30000 rows x 2 columns]

# %%
answers = []
for index, row in df.iterrows():
    answer = row['answers'][17:row['answers'].find("]")-1]
    answers.append(answer)
qa_df['answers'] = answers

# %%
qa_df.head()
# Out:
#                                             question  \
# 0   What sare the benifts of the blood brain barrir?
# 1         What is surrounded by cerebrospinal fluid?
# 2                       What does the skull protect?
# 3  What has been injected into rats to produce pr...
# 4    What can cause issues with how the brain works?
#
#                                              context  \
# 0  Another approach to brain function is to exami...
# 1  Another approach to brain function is to exami...
# 2  Another approach to brain function is to exami...
# 3  Another approach to brain function is to exami...
# 4  Another approach to brain function is to exami...
#
#                          answers
# 0  isolated from the bloodstream
# 1                          brain
# 2                          brain
# 3                      chemicals
# 4                   brain damage

# %%
qa_dataset = Dataset.from_pandas(qa_df.sample(1000, random_state = 42))
qa_dataset = qa_dataset.train_test_split(test_size = 0.2)

# %%
def preprocess(data):
    return bert_tokenizer(data['question'], data['context'], truncation = True)

# %%
qa_dataset = qa_dataset.map(preprocess, batched = True)
# Out:
# Map:   0%|          | 0/800 [00:00<?, ? examples/s]
# Map:   0%|          | 0/200 [00:00<?, ? examples/s]

# %%
for name, param in qa_bert.bert.named_parameters():
    if 'encoder.layer.22' in name:
        break
    param.requires_grad = False

# %%
data_collator = DataCollatorWithPadding(tokenizer = bert_tokenizer)

# %%
batch_size = 32
epochs = 2
training_args = TrainingArguments(
    output_dir = './qa/results',
    num_train_epochs = epochs,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    logging_dir='./qa/logs',
    save_strategy='epoch',
    logging_steps=10,
    evaluation_strategy='epoch',
    load_best_model_at_end=True
)

trainer = Trainer(
    model = qa_bert,
    args = training_args,
    train_dataset = qa_dataset['train'],
    eval_dataset = qa_dataset['test'],
    data_collator = data_collator
)

# %%
trainer.evaluate()
# Out:
#     <div>
#
#       <progress value='4' max='7' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4/7 24:36 < 24:36, 0.00 it/s]
#     </div>

# %%
answers
# Out:
# [' bloodstre',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ' dama',
#  '',
#  ' use electrodes or locally injected chemicals to produce precise patterns of dama',
#  '',
#  'ral types of dama',
#  '',
#  '',
#  '',
#  '',
#  ' in the bo',
#  '',
#  '',
#  'control the e',
#  'tions from the bra',
#  '',
#  's such as walking or swimmi',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'balance, taste, and sme',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ower bra',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ' cort',
#  ' to the subcortical motor areas, but also sends a massive projection directly to the spinal co',
#  '',
#  '',
#  '',
#  'basal ganglia, and cerebell',
#  '',
#  'ex, basal ganglia, and cerebell',
#  ' cortex sends projections to the subcortical motor areas, but also sends a massive projection directly to the spinal co',
#  'g, or swallowi',
#  ' to the subcortical motor areas, but also sends a massive projection directly to the spinal co',
#  't',
#  '',
#  'nificance of the issue and the degree of cohesion within the majority par',
#  'arty Strategi',
#  'arty cohesi',
#  '',
#  '',
#  'arty Strategi',
#  'es availab',
#  'riven by internal dissensi',
#  'in consultation with other party colleagu',
#  '',
#  '',
#  'nced his retirement and had little or no involvement in the campai',
#  ' many Republicans by objecting to their private bills on the flo',
#  'electio',
#  '',
#  '',
#  '',
#  'ways elevated their minority floor leader to the speakership upon reclaiming majority stat',
#  'nounced his retirement and had little or no involvement in the campai',
#  '',
#  '',
#  '',
#  '',
#  'ad',
#  '',
#  '',
#  'for other offices so as to hold down the number of open seats the party would need to defe',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  "ementing his party's strategy on the floor with respect to promoting or opposing legislati",
#  'tive busine',
#  'sing legislati',
#  '',
#  '',
#  "rs serving on House committees, and with the members of the party's whip organizati",
#  '',
#  'par',
#  '',
#  '',
#  ' may not be a winning strategy if his party fails to offer policy alternativ',
#  '',
#  'and media attenti',
#  'rnativ',
#  '',
#  'er may be able to launch a campaign against a "do-nothing Congres',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'suni',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ' Amendments to the state constitution pass',
#  'ourt ruled on appeal that the congressional districts had to be redra',
#  '',
#  '',
#  '',
#  'tricts had to be redra',
#  'me Court ruled on appe',
#  'istricti',
#  'ou',
#  ' redistricti',
#  ' Amendments to the state constitution pass',
#  '',
#  'me Court ruled on appe',
#  '',
#  '',
#  '',
#  '',
#  'da ar',
#  '',
#  '',
#  '',
#  'gregation, disfranchisement and agricultural depressi',
#  '',
#  '',
#  '',
#  'egal syst',
#  'rnme',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ' NASCAR race weeke',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'unstressed a and',
#  '',
#  '',
#  '',
#  '',
#  'ce lies in the treatment of unstressed a and e; which have merged to /ə/ in Eastern dialec',
#  'unstressed a and',
#  'ce lies in the treatment of unstressed a and e; which have merged to /ə/ in Eastern dialects, but which remain distinct as /a/ and /e/ in Western dialec',
#  'al bloc',
#  'and Western Catal',
#  'unstressed a and',
#  's /a/ and /e/ in Western dialec',
#  'in two major dialectal blocks: Eastern Catalan, and Western Catal',
#  'nd /',
#  '',
#  '',
#  '',
#  ' the County of Barcelona from the Carolingian Empi',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'n; and 73% with Romani',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'n (except Majorcan), unstressed vowels reduce to three: /a e ɛ/ >',
#  '',
#  ' reduce to thr',
#  '',
#  '',
#  '',
#  '',
#  'a',
#  '',
#  'atalan is mandatory in all schoo',
#  ' shi',
#  '',
#  ' use Spani',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'cian schola',
#  '',
#  'he Valencian peop',
#  ' of Valencian Culture (Acadèmia de Cultura Valenciana, RAC',
#  'n different from Catal',
#  '',
#  'he Valencian peop',
#  'ns educated in Valenci',
#  '',
#  ' use Valencian regular',
#  'ra Valenciana, RA',
#  'ra Valencia',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '.siˈa',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'eral Party to fill a Senate vacan',
#  'g display on the lawns of Parliame',
#  'mentary spee',
#  '',
#  'me',
#  'ection at the 1972 electi',
#  'mentary spee',
#  'al Senat',
#  'cial welfare issu',
#  'g displ',
#  'Australian in the Australian Parliame',
#  'cial welfare issu',
#  'vacan',
#  'Par',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'rve in an Australian Cabin',
#  'hite Australia Poli',
#  'Commerce between Australia and Jap',
#  '',
#  ' trade with Jap',
#  '',
#  'the United Stat',
#  'c aid to underdeveloped natio',
#  '',
#  '',
#  'e Communist Party of China to pow',
#  'outh Korea by Communist North Kor',
#  '',
#  'ps to the Korean War and attempted to ban the Communist Party of Austral',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ' Kans',
#  '',
#  'fice',
#  '',
#  '',
#  '',
#  '',
#  "n Clausewitz's On W",
#  '',
#  '',
#  '',
#  '',
#  'harge of Pacific Defenses under the Chief of War Plans Division (WPD), General Leonard T. Gerow, and then succeeded Gerow as Chief of the War Plans Division. Next, he was appointed Assistant Chief of Staff in charge of the new Operations Divisi',
#  '',
#  'new Operations Divisi',
#  'n Pearl Harb',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ly at arms contr',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'next w',
#  '',
#  '',
#  "MacArthur against taking a public role in it, he later wrote the Army's official incident report, endorsing MacArthur's condu",
#  '',
#  '',
#  'cu',
#  'rship and diploma',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'e Gaul',
#  'n the Allied comma',
#  'nard Montgome',
#  '',
#  'de',
#  ' in Taiw',
#  '',
#  '',
#  '',
#  'for conventional military forc',
#  'fici',
#  '',
#  '',
#  '',
#  ' of Chi',
#  '',
#  ' of Chi',
#  '',
#  '',
#  '',
#  '',
#  '. Department of the Treasu',
#  '',
#  ' succe',
#  'mbia Universi',
#  't a professional writ',
#  '. Department of the Treasu',
#  '',
#  'mbia Universi',
#  '',
#  '',
#  'Golf Cl',
#  's post in New Yo',
#  'ormal Chairman of the Joint Chiefs of Staff in Washingt',
#  '',
#  'ormal Chairman of the Joint Chiefs of Staff in Washingt',
#  '',
#  '',
#  's post in New Yo',
#  '',
#  's post in New Yo',
#  'pa',
#  '',
#  '',
#  '',
#  'gone missin',
#  ' reportedly shot do',
#  'ave fallen unconscio',
#  '',
#  '',
#  '',
#  '',
#  'pa',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'al delegate votes from Tex',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '200',
#  '',
#  'ci',
#  '',
#  '',
#  '',
#  'han',
#  '',
#  'han',
#  '2000s (decad',
#  '',
#  'the East and West, competitive cost structure and a highly skilled labour for',
#  'structu',
#  'om Taani linna (meaning Danish town or castl',
#  '',
#  "h influence can be seen in heraldic symbols. The Danish cross is on the city of Tallinn's coat of arms, and Estonia's coat of arms displays three lions similar to those found on the Danish coat of ar",
#  '',
#  '',
#  '',
#  ' Lübeck city rights (124',
#  "is on the city of Tallinn's coat of arms, and Estonia's coat of arms displays three lions similar to those found on the Danish coat of ar",
#  '',
#  '',
#  '',
#  'i linna (meaning Danish town or castl',
#  '',
#  'anis',
#  '',
#  '',
#  '',
#  'e',
#  "ountry's domestic and foreign poli",
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'lopme',
#  'members of the parliament to observe the activities of the executive power and the above-mentioned high officials of the sta',
#  'n',
#  'rliame',
#  'ational Cou',
#  '',
#  'cts and appoints several high officials of the sta',
#  ' the executive power and the above-mentioned high officials of the sta',
#  'oints, on the proposal of the President of Eston',
#  'f the President of Eston',
#  ' the sta',
#  'Eston',
#  'oints, on the proposal of the President of Eston',
#  'the Republ',
#  'he National Court, the chairman of the board of the Bank of Estonia, the Auditor General, the Legal Chancellor and the Commander-in-Chief of the Defence Forc',
#  ' the sta',
#  '',
#  '',
#  '',
#  'ject to deal wi',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'allinn Song Festival Grounds (Lauluväljak) have hosted the event every five years in July. The last festival took place in July 20',
#  '',
#  '',
#  't amateur choral events in the wor',
#  '',
#  '',
#  'tiva',
#  '',
#  '',
#  'm',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'he',
#  '',
#  'ed by the Soviet Union as the Estonian S',
#  ' death by Soviet tribuna',
#  '',
#  '',
#  '',
#  '',
#  'nary peop',
#  '',
#  "ry's political and intellectual leaders were killed or deported to remote areas of the USSR by the Soviet authoriti",
#  '',
#  '',
#  'nary peop',
#  'ed by the Soviet Uni',
#  '',
#  'thern Estonia and Saaremaa rebelled against German ru',
#  'ori',
#  '',
#  '',
#  '',
#  'a',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'i',
#  '',
#  '',
#  '',
#  ' of Estonian language literature, theatre and professional mus',
#  'ist moveme',
#  'oo',
#  '',
#  '',
#  'o',
#  'schu',
#  'pread from 19',
#  '',
#  'st to the selective school system, where admission is restricted on the basis of selection criter',
#  'ish secondary school pupils now attend comprehensive schoo',
#  '',
#  'oo',
#  'syst',
#  'o',
#  '',
#  'cho',
#  '',
#  'hern Ireland differs slight',
#  '',
#  'hern Ireland differs slightly from systems used elsewhere in the United Kingd',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  've scho',
#  'comprehensive schools since the 197',
#  '',
#  '',
#  '',
#  'ower comprehensive school (grades 1–6, ala-aste, alakoulu) and upper comprehensive school (grades 7–9, yläaste, yläkoulu) has been discontinu',
#  '',
#  '',
#  'ruskou',
#  '',
#  '',
#  ' comprehensive school (grades 1–6, ala-aste, alakoulu) and upper comprehensive scho',
#  '',
#  '',
#  '',
#  '',
#  'dents attendi',
#  'r',
#  '',
#  '',
#  '',
#  '',
#  'denbu',
#  '',
#  '',
#  'bili',
#  '',
#  '',
#  '',
#  'e for Educati',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'o',
#  'o',
#  '',
#  '',
#  'r',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'sic publishing busine',
#  'us resolv',
#  '',
#  'forwa',
#  'cle',
#  '',
#  ' status resolv',
#  '',
#  'were cle',
#  '',
#  'oner Pedro Pierluisi, Governor Luis Fortuño, and Governor-elect Alejandro García Padilla wrote separate letters to the President of the United States Barack Obama addressing the results of the voti',
#  '',
#  'e voti',
#  '',
#  '',
#  ' to move the process forward. García Padilla asked him to reject the results because of their ambigui',
#  'Puerto Ri',
#  '',
#  '',
#  'ena',
#  '',
#  '',
#  '',
#  '',
#  'emocracy Act (H.R. 2499) was approved on April 29, 2010, by the United States House of Representatives 223–169, but was not approved by the Senate before the end of the 111th Congre',
#  '.S. at bir',
#  'ia',
#  'e of the U.S. Constituti',
#  '',
#  'he name of Estado Libre Asociado (literally translated as "Free Associated Stat',
#  '',
#  '',
#  "to the respective parties' national conventio",
#  '',
#  '',
#  '',
#  '',
#  'ary or caucus of the Democratic Party and the Republican Par',
#  'on',
#  'sion',
#  '',
#  'e of the 50 states or the District of Columb',
#  'respective parti',
#  '',
#  '',
#  '',
#  '',
#  'ri',
#  ' re-admission poli',
#  '',
#  '',
#  "nt after Lincoln's assassination in 18",
#  ' had ratified the Fourteenth Amendment, it was the only one of the formerly secessionist states that did not have a military governor during the Reconstruction peri',
#  ' first of the seceding states to have its elected members readmitted to the U.S. Congre',
#  '',
#  '',
#  '',
#  ' re-admission poli',
#  ' re-admission poli',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'oudoun end',
#  ' settlement in what is now Tennessee was bui',
#  'emeré relinquished comma',
#  'rces under British Captain Raymond Deme',
#  '',
#  ' settlement in what is now Tennessee was bui',
#  ' settlement in what is now Tennessee was bui',
#  ' settlement in what is now Tennessee was bui',
#  'emeré relinquished comma',
#  'emeré relinquished command on August 14, 1757 to his broth',
#  'ré and a number of his men were kill',
#  ' before the 196',
#  '',
#  'n are',
#  'ph',
#  'f the four major cities, and is particularly strong in the cities of Nashville and Memph',
#  '',
#  'e 18',
#  'd Knoxvil',
#  'nd 2nd congressional distric',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ere',
#  '',
#  '',
#  '',
#  'quarters of the ordinarily resident population could speak Norf',
#  '',
#  't is spoken by descendants of the first free settlers of Norfolk Island who were descendants of the settlers of Pitcairn Isla',
#  '',
#  '',
#  '',
#  'cial language of the isla',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'b',
#  'ality l',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ality l',
#  'ality l',
#  '',
#  'i',
#  '',
#  '',
#  'tizens who are Australian permanent residen',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'al',
#  '',
#  '',
#  'inke whale, sei whale, and dolphi',
#  '',
#  '',
#  ' official Famicom cartridges were produced in many colors of plast',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ' in design to the popular accessory Game Genie, are available that allow Famicom games to be played on an N',
#  '',
#  ' interface, the Famicom system used a 60-pin desi',
#  'll',
#  '',
#  '',
#  'ing caught in the controller casi',
#  '',
#  '',
#  '',
#  'back of the conso',
#  'tto',
#  'ird-party publishing until Mediagen',
#  'ird-party publishing until Mediagenic in late summer 19',
#  '',
#  '',
#  '',
#  ' made the company many enemi',
#  "lishers' requests for cartridg",
#  '',
#  'd all the ri',
#  "al company brands like Konami's Ultra Games lab",
#  '',
#  '',
#  'allow video game mark',
#  'p syst',
#  '',
#  '',
#  'ga',
#  'ed approv',
#  '',
#  '',
#  'y close representation of the actual onscreen graphics of the ga',
#  'ict product approval and licensing poli',
#  '',
#  '',
#  "ion's front featur",
#  '',
#  'i',
#  '',
#  '',
#  '',
#  '',
#  'a',
#  '',
#  'n the executive and the organizati',
#  'aff including management, whereas others employ unpaid volunteers and even executives who work with or without compensation (occasionally nomina',
#  '',
#  'aff including management, whereas others employ unpaid volunteers and even executiv',
#  'out compensati',
#  'vironments and implacable wo',
#  "NPO's are well-funded and comparative to their public sector competetito",
#  'e sect',
#  'ti',
#  'mploye',
#  '',
#  '',
#  'orke',
#  '',
#  '',
#  "tart a new program without disclosing its complete liabilities. The employee may be rewarded for improving the NPO's reputation, making other employees happy, and attracting new dono",
#  '',
#  'sed on the full faith and credit of the organization but not recorded anywhere constitute accounting fra',
#  'atio',
#  '',
#  '',
#  '',
#  '',
#  'at',
#  'atio',
#  'cant funding from large for-profit corporatio',
#  '',
#  '',
#  'atio',
#  '',
#  '',
#  '',
#  '',
#  'ati',
#  'ng World War ',
#  '',
#  'd',
#  '',
#  'ntion on the Prevention and Punishment of the Crime of Genocide (CPPCG) which defined the crime of genoci',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'd',
#  '',
#  'nd Drago Nikol',
#  ' Human Righ',
#  '',
#  '',
#  'rity forc',
#  '',
#  '',
#  'nd Drago Nikol',
#  'nd Drago Nikol',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ncluding the US',
#  '',
#  '',
#  'Congre',
#  'Brazil, Peru, Venezuela, the Philippines, the Dominican Republic, Iran, Egypt, Belgium, and Urugu',
#  '',
#  "the Convention's definition should follow the etymology of the te",
#  'Congre',
#  '',
#  'ion of the travaux fails to confirm a popular impression in the literature that the opposition to inclusion of political genocide was some Soviet machinati',
#  '',
#  'mi',
#  '',
#  'o establish any geographic or social common denominat',
#  '',
#  '',
#  '',
#  'were also shared by a number of other States for whom it is difficult to establish any geographic or social common denominator: Lebanon, Sweden, Brazil, Peru, Venezuela, the Philippines, the Dominican Republic, Iran, Egypt, Belgium, and Urugu',
#  ' also shared by a number of other States for whom it is difficult to establish any geographic or social common denominat',
#  'iticid',
#  ' sta',
#  '',
#  '',
#  '',
#  '',
#  '',
#  ...]

# %%
df.iloc[0]['answers']
# Out:
# "{'text': array(['isolated from the bloodstream'], dtype=object), 'answer_start': array([195])}"

# %%
import pandas as pd

def extract_positions(file_path):
    # Load dataset
    df = pd.read_csv(file_path)
    
    # Ensure required columns exist
    required_columns = {'question', 'context', 'answers'}
    if not required_columns.issubset(df.columns):
        raise ValueError(f"Dataset must contain columns: {required_columns}")
    
    start_positions = []
    end_positions = []
    
    for index, row in df.iterrows():
        question = row['question'].split()
        context = row['context'].split()
        answer = row['answers'][17:row['answers'].find("]")-1]
        answer = answer.split()
#         start_pos = context.find(answer[0])
        try:
            start_pos = next(i for i in range(len(context)) if context[i:i+len(answer)] == answer) 
            end_pos = start_pos + len(answer) - 1
        except StopIteration:
            start_pos = -1e5
            end_pos = -1e5
        start_positions.append(start_pos)
        end_positions.append(end_pos)
    
    # Add new columns
    df['start_position'] = start_positions
    df['end_position'] = end_positions
    
    # Save to a new CSV file
    output_path = file_path.replace('.csv', '_processed.csv')
    df.to_csv(output_path, index=False)
    print(f"Processed file saved as: {output_path}")
    
    return df

# Run function on uploaded file
df_processed = extract_positions('data/qa.csv')
df_processed.head()
# Out:
# Processed file saved as: data/qa_processed.csv
#    Unnamed: 0                                        id  title  \
# 0           0  7ba1e8f4261d3170fcf42e84a81dd749116fae95  Brain
# 1           1  5ec5ef305a259311596e85d811ade30bd68b079d  Brain
# 2           2  7cb230edfb15ad1fda8d157af1f2b574cbb02b4c  Brain
# 3           3  e1850f2a48b8f7c2231cec41ed63c1b638a8e2c7  Brain
# 4           4  7bc0ae1a8a24ea4f3398b5236ab9569bbc3e820b  Brain
#
#                                              context  \
# 0  Another approach to brain function is to exami...
# 1  Another approach to brain function is to exami...
# 2  Another approach to brain function is to exami...
# 3  Another approach to brain function is to exami...
# 4  Another approach to brain function is to exami...
#
#                                             question  \
# 0   What sare the benifts of the blood brain barrir?
# 1         What is surrounded by cerebrospinal fluid?
# 2                       What does the skull protect?
# 3  What has been injected into rats to produce pr...
# 4    What can cause issues with how the brain works?
#
#                                              answers  \
# 0  {'text': array(['isolated from the bloodstream...
# 1  {'text': array(['brain'], dtype=object), 'answ...
# 2  {'text': array(['brain'], dtype=object), 'answ...
# 3  {'text': array(['chemicals'], dtype=object), '...
# 4  {'text': array(['brain damage'], dtype=object)...
#
#                                             metadata  start_position  \
# 0  {'split': 'train', 'model_in_the_loop': 'Combi...            31.0
# 1  {'split': 'train', 'model_in_the_loop': 'Combi...             3.0
# 2  {'split': 'train', 'model_in_the_loop': 'Combi...             3.0
# 3  {'split': 'train', 'model_in_the_loop': 'Combi...           115.0
# 4  {'split': 'train', 'model_in_the_loop': 'Combi...            66.0
#
#    end_position
# 0          34.0
# 1           3.0
# 2           3.0
# 3         115.0
# 4          67.0

# %%
qa_df = df_processed[['question', 'context', 'start_position', 'end_position']]

# %%
qa_df.head()
# Out:
#                                             question  \
# 0   What sare the benifts of the blood brain barrir?
# 1         What is surrounded by cerebrospinal fluid?
# 2                       What does the skull protect?
# 3  What has been injected into rats to produce pr...
# 4    What can cause issues with how the brain works?
#
#                                              context  start_position  \
# 0  Another approach to brain function is to exami...            31.0
# 1  Another approach to brain function is to exami...             3.0
# 2  Another approach to brain function is to exami...             3.0
# 3  Another approach to brain function is to exami...           115.0
# 4  Another approach to brain function is to exami...            66.0
#
#    end_position
# 0          34.0
# 1           3.0
# 2           3.0
# 3         115.0
# 4          67.0

# %%
bert_tokenizer.decode(bert_tokenizer.encode(qa_df.iloc[0].question, qa_df.iloc[0].context)[56:61])
# Out:
# 'isolated from the bloodstream'

# %%
qa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   question        30000 non-null  object
#  1   context         30000 non-null  object
#  2   start_position  17194 non-null  float64
#  3   end_position    17194 non-null  float64
# dtypes: float64(2), object(2)
# memory usage: 937.6+ KB

# %%
qa_df.isnull
# Out:
# <bound method DataFrame.isnull of                                                 question  \
# 0       What sare the benifts of the blood brain barrir?
# 1             What is surrounded by cerebrospinal fluid?
# 2                           What does the skull protect?
# 3      What has been injected into rats to produce pr...
# 4        What can cause issues with how the brain works?
# ...                                                  ...
# 29995                  What is the lowest ISO mentioned?
# 29996                 What is the highest ISO mentioned?
# 29997              What is Kodak'sbrand name of E6 film?
# 29998                         How do these films differ?
# 29999  What letter designates what Ektachrome is desi...
#
#                                                  context  start_position  \
# 0      Another approach to brain function is to exami...            31.0
# 1      Another approach to brain function is to exami...             3.0
# 2      Another approach to brain function is to exami...             3.0
# 3      Another approach to brain function is to exami...           115.0
# 4      Another approach to brain function is to exami...            66.0
# ...                                                  ...             ...
# 29995  Some high-speed black-and-white films, such as...             NaN
# 29996  Some high-speed black-and-white films, such as...             8.0
# 29997  Some high-speed black-and-white films, such as...            80.0
# 29998  Some high-speed black-and-white films, such as...             NaN
# 29999  Some high-speed black-and-white films, such as...             NaN
#
#        end_position
# 0              34.0
# 1               3.0
# 2               3.0
# 3             115.0
# 4              67.0
# ...             ...
# 29995           NaN
# 29996           8.0
# 29997          80.0
# 29998           NaN
# 29999           NaN
#
# [30000 rows x 4 columns]>
